# %%
# update pip and setuptools
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install --upgrade setuptools

# %%
# install lib_platform
# !{sys.executable} -m pip install lib_platform

# %%
import lib_platform

# %%
# get system as string
lib_platform.system

# %%
# bool is_platform_linux
lib_platform.is_platform_linux

# %%
# bool is_platform_darwin
lib_platform.is_platform_darwin

# %%
# bool is_platform_posix
# either darwin or linux
lib_platform.is_platform_posix

# %%
# bool is_platform_windows
# also True for windows_xp or windows_wine
lib_platform.is_platform_windows

# %%
# bool is_platform_windows_xp
lib_platform.is_platform_windows_xp

# %%
# bool is_platform_windows_wine
lib_platform.is_platform_windows_wine

# %%
# bool is_platform_windows_wine_xp
lib_platform.is_platform_windows_wine_xp

# %%
# string username lib_platform.username
lib_platform.username

# %%
# string fqdn hostname
lib_platform.hostname

# %%
# string hostname short
lib_platform.hostname_short

# %%
# path to userhome
lib_platform.path_userhome

# %%
# is user administrator (has user admin rights)
lib_platform.is_user_admin
